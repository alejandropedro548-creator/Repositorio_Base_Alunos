# %%
while True:
    pergunta = input("Qual o numero do seu clush ?")
    if pergunta == "40028922":
        print(" neymar ? que beleza 😋")
        break
    else:
        print("você é burro ?")
# Out:
#  neymar ? que beleza 😋

# %%
while True:
    pergunta = int(input("Digite um numero inteiro"))
    if pergunta == 3:
        print("ganhou 100zin")
        break
    else:
        print("Numero errado, tente novamente")
# Out:
# ganhou 100zin

# %%
while True:
    pergunta = input("Wender(Motoboy) é viado,burro,repetente e frita os gatos dele pra comer ?")
    if pergunta == "sim":
        print("Parabéns, acertou")
        break
    else:
        print("Acho que sim em")
# Out:
# Acho que sim em
# Acho que sim em
# Parabéns, acertou

# %%
while True:
    pergunta = int(input("Em qual ano estamos ?"))
    if pergunta == 2025:
        print("Acertou, Genio")
        break
    else:
        print("Você é Repelente ao conhecimento, imune ao ensino, inteligente ao contrario")
# Out:
# Você é Repelente ao conhecimento, imune ao ensino, inteligente ao contrario
# Você é Repelente ao conhecimento, imune ao ensino, inteligente ao contrario
# Acertou, Genio

# %%
numero = int(input("Digite um número :"))
numero_anterior = numero - 1
numero_sucessor = numero + 1
print(f"O número que você digitou foi: {numero}")
print(f"O número anterior do número escolhido ({numero}) é: {numero_anterior}")
print(f"O número sucessor do número escolhido ({numero}) é: {numero_sucessor}")
# Out:
# O número que você digitou foi: 7
# O número anterior do número escolhido (7) é: 6
# O número sucessor do número escolhido (7) é: 8

# %%
numero = int(input("Digite um número"))
for i in range(numero):
    print(f"numero: {i}")
# Out:
# numero: 0
# numero: 1
# numero: 2
# numero: 3
# numero: 4
# numero: 5
# numero: 6
# numero: 7

# %%
contatinho = int(input("Quantos contatinhos você tem: "))
for i in range(contatinho):
    nomes = input("Digite o nome dos contatinhos: ")
    print(nomes)
# Out:
# motosauro

# %%
time = input("Digite o nome do seu time: ")
mundial = int(input("Quantos mundiais seu time tem ?"))
for mundial in range(mundial):
    ano = input("Digite o ano que ele foi campeão:")
    print(f"O Seu time: {time}, foi campeão mundial em {ano}")
# Out:
# O Seu time: Real Madrid, foi campeão mundial em 1960
# O Seu time: Real Madrid, foi campeão mundial em 1998
# O Seu time: Real Madrid, foi campeão mundial em 2002
# O Seu time: Real Madrid, foi campeão mundial em 2014
# O Seu time: Real Madrid, foi campeão mundial em 2016
# O Seu time: Real Madrid, foi campeão mundial em 2017
# O Seu time: Real Madrid, foi campeão mundial em 2018
# O Seu time: Real Madrid, foi campeão mundial em 2022
# O Seu time: Real Madrid, foi campeão mundial em 2024

# %%
quantidade = int(input("Digite quantos membros tem na sua família: "))
membros = []
for i in range(quantidade):
    nome = input("Digite o nome dos membros: ")
    membros.append(nome)
print("Membros da família:", membros)
if len(membros) >= 5:
    print("Uau, Que família grande")
else:
    print("Que família pequena")
# Out:
# Membros da família: ['Pedro', 'Javier', 'Nerivan', 'Feroz', 'Banana', 'daiane', 'ester', 'melissa']
# Uau, Que família grande

# %%
hobbies = int(input("Digite quantos hobbies você tem: "))
for hobbies in range(hobbies):
    nome_hobbies = input("Digite os Hobbies: ")
    print(nome_hobbies)
# Out:
# estudar
# me exercitar
# adestrar caes

# %%
quantidade = int(input("Digite a quantas notas você tem ? "))
notas = []
for quantidade in range(quantidade):
    nota = float(input("Digite suas notas: "))
    notas.append(nota)
print("Suas notas são:", notas)
if nota > 7:
    print("Boa!!!")
else:
    print("Sou imune ao conhecimento")
# Out:
# Suas notas são: [10.0, 10.0, 10.0]
# Boa!!!

# %%
quantidade = int(input("Digite quantos produtos você deseja comprar? "))
produtos = []
valores = []
for quantidade in range(quantidade):
    nome = (input("Digite o nome do produto: "))
    valor = float(input("Digite o valor do produto: "))
    produtos.append(nome)
    valores.append(valor)
print("O preço foi:", valores)
print("Seus produtos comprados são:", produtos)

if valor > 50:
    print("tá caro!!!")
elif valor >=40 and valor <= 45:
    print("está ok")
else:
    print("Baratinho até o motoboy compra")
# Out:
# O preço foi: [10.0]
# Seus produtos comprados são: ['chocolate']
# Baratinho até o motoboy compra

# %%
quantidade = int(input("Digite quantos apelidos você ?"))
apelidos = []
for i in range(quantidade):
    apelido = input("Digite o seu apelido")
    apelidos.append(apelido)
print(f"então esses são seus apelidos ? {apelidos} que legal")
# Out:
# então esses são seus apelidos ? ['cutucador de utero', 'pomba grossa'] que legal

# %%
while True:
    pergunta = (input("Matheus é o melhor professor?"))
    if pergunta == "sim":
        print("Acertou, Genio")
        break
    else:
        print("Você é Repelente ao conhecimento, imune ao ensino, inteligente ao contrario")
# Out:
# Você é Repelente ao conhecimento, imune ao ensino, inteligente ao contrario
# Acertou, Genio
