# %%
### Pegar a nota da prova teórica
### Pedir pro usúario
### Pedir pro Usúario a nota da prova prática
### Calcule a Média
### Como eu calculo a Média ??? se você não souber já reprovou
### se a média for maior que 7, print("Aprovado")
### se não, reprovado
teorica = float(input("Digite a nota da prova teórica: "))
pratica = float(input("Digite a nota da prova prática: "))

max = teorica + pratica
media = max / 2

if media >= 7:
    print(f"Sua média foi de: {media} e você foi Aprovado")

else:
    print(f"Sua média foi de: {media} e você foi Reprovado")
# Out:
# Sua média foi de: 9.5 e você foi Aprovado

# %%
### listas vazias
artistas = []
musicas = []

### Pergunte a quantidade de músicas a ser adicionada na playlist
quantidade = int(input("Digite a quantidade de música que você deseja adicionar: "))

for i in range(quantidade):
    artista = input("Digite o nome do artista: ")
    musica = input("Digite o nome da música: ")
    artistas.append(artista)
    musicas.append(musica)
print(f"Óla, os seus artistas escolhidos foram: {artistas}. Um Ótimo gosto 🔥")
print(F"E as suas músicas escolhidas foram: {musicas}. 🎶")
# Out:
# Óla, os seus artistas escolhidos foram: ['Plabo Vittar']. Um Ótimo gosto 🔥
# E as suas músicas escolhidas foram: ['K.O']. 🎶

# %%
for i in artistas:
    if [i] == "Plabo Vittar":
        print("Você é o motoboy")
    else:
        print(i)
# Out:
# Plabo Vittar
