# %% [markdown]
# # Introdução prática ao Gemini API — Free Tier
#
# Este notebook mostra o básico para interagir com uma IA usando a **Gemini API** em Python.
#
# Você vai aprender a:
#
# 1. instalar a biblioteca oficial `google-genai`;
# 2. configurar a chave da API;
# 3. enviar uma pergunta simples para o Gemini;
# 4. usar instrução de sistema;
# 5. controlar criatividade com `temperature`;
# 6. criar um chat simples com histórico;
# 7. gerar respostas estruturadas em JSON.
#
# > Material pensado para Google Colab e para uso didático em aula.

# %% [markdown]
# ## 1. Instalação da biblioteca
#
# A biblioteca `google-genai` permite acessar os modelos Gemini usando Python.
#
# No Google Colab, execute a célula abaixo para instalar o pacote.

# %%
# !pip -q install google-genai
# Out:
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Configuração da chave da API
#
# Para usar a Gemini API, você precisa de uma chave de API.
#
# Ela pode ser criada no Google AI Studio.
#
# Nesta célula, usamos `getpass` para esconder a chave enquanto ela é digitada.

# %%
import os
import getpass

os.environ["GEMINI_API_KEY"] = getpass.getpass("Cole sua GEMINI_API_KEY: ")
# Out:
# Cole sua GEMINI_API_KEY:  ········

# %% [markdown]
# ## 3. Criando o cliente Gemini
#
# O cliente é o objeto responsável por se comunicar com a API do Gemini.

# %%
from google import genai

cliente = genai.Client(api_key=os.environ["GEMINI_API_KEY"])

# %% [markdown]
# ## 4. Escolhendo o modelo
#
# Para aulas e testes rápidos no free tier, modelos da família **Flash** costumam ser uma boa escolha.
#
# Caso o modelo abaixo não esteja disponível na sua conta, troque por outro modelo Flash disponível no Google AI Studio.

# %%
MODELO = "gemini-2.5-flash"

# %% [markdown]
# ## 5. Primeira pergunta para a IA
#
# Agora vamos enviar uma pergunta simples para testar se a conexão está funcionando.

# %%
resposta = cliente.models.generate_content(
    model=MODELO,
    contents="Explique em poucas palavras o que é inteligência artificial."
)

print(resposta.text)
# Out:
# IA é a capacidade de sistemas e máquinas **realizarem tarefas** que normalmente exigiriam **inteligência humana**, como aprender, raciocinar e tomar decisões.

# %% [markdown]
# ## 6. Criando uma função para perguntar ao Gemini
#
# Agora vamos organizar o código em uma função reutilizável.
#
# Assim, sempre que quisermos fazer uma pergunta, basta chamar `perguntar_ao_gemini()`.

# %%
def perguntar_ao_gemini(pergunta: str) -> str:
    """
    Envia uma pergunta para o Gemini e retorna a resposta em texto.
    """

    resposta = cliente.models.generate_content(
        model=MODELO,
        contents=pergunta
    )

    return resposta.text

# %%
resposta = perguntar_ao_gemini("Me dê 3 exemplos de uso de IA no dia a dia.")
print(resposta)
# Out:
# A Inteligência Artificial já está tão integrada ao nosso dia a dia que muitas vezes nem percebemos! Aqui estão 3 exemplos comuns:
#
# 1.  **Assistentes Virtuais por Voz (Siri, Alexa, Google Assistant):** Quando você pede para o seu smartphone tocar uma música, perguntar a previsão do tempo ou adicionar um item à sua lista de compras, você está interagindo com IA. Esses assistentes usam processamento de linguagem natural (PLN) para entender o que você diz, reconhecimento de fala para converter sua voz em texto e algoritmos de IA para buscar informações e executar tarefas.
#
# 2.  **Sistemas de Recomendação (Netflix, Spotify, Amazon):** Sabe aquelas sugestões de filmes, séries, músicas ou produtos que parecem "ler sua mente"? Isso é IA em ação! Esses sistemas analisam seu histórico de visualizações/compras, o que você gostou, o que outros usuários com gostos parecidos viram, e até mesmo fatores demográficos para prever o que você provavelmente vai querer ver ou comprar a seguir.
#
# 3.  **Aplicativos de Navegação (Google Maps, Waze):** Ao usar apps para encontrar a melhor rota, prever o tempo de chegada ou desviar do trânsito, você está se beneficiando da IA. Esses aplicativos usam algoritmos complexos que processam dados em tempo real (velocidade de outros usuários, acidentes, obras), dados históricos de tráfego e Machine Learning para calcular a rota mais eficiente e prever com precisão quanto tempo sua viagem levará.

# %% [markdown]
# ## 7. Usando uma instrução de sistema
#
# A **instrução de sistema** define como a IA deve se comportar.
#
# Exemplo: responder em português, ser objetiva, agir como professora, explicar passo a passo etc.

# %%
INSTRUCAO_SISTEMA = (
    "Você é um professor de tecnologia. "
    "Explique os assuntos em português do Brasi, "
    "com linguagem simples, exemplos práticos e sem respostas longas demais."
)

resposta = cliente.models.generate_content(
    model=MODELO,
    contents="Explique como é ter 10 dedos.",
    config={
        "system_instruction": INSTRUCAO_SISTEMA
    }
)

print(resposta.text)
# Out:
# E aí, turma!
#
# Ter 10 dedos, na nossa "linguagem de tecnologia", é como ter a **interface de usuário mais versátil e intuitiva** que existe para interagir com o mundo físico. Pensa neles como 10 pequenos **sensores e atuadores** altamente treinados e coordenados!
#
# Vamos lá, na prática:
#
# 1.  **Precisão e Destreza (Fine Motor Skills):** Com eles, a gente consegue fazer coisas que exigem uma precisão absurda. Pensa em:
#     *   Digitar rápido no teclado.
#     *   Digitar mensagens no celular com os polegares.
#     *   Pegar um grãozinho de arroz.
#     *   Montar um LEGO minúsculo.
#     *   Passar a linha na agulha.
#
# 2.  **Força e Manipulação (Grip and Control):** Ao mesmo tempo, eles dão força e controle. Com a palma da mão e os dedos trabalhando juntos, você consegue:
#     *   Segurar um copo d'água.
#     *   Abrir uma porta girando a maçaneta.
#     *   Carregar sacolas de supermercado.
#     *   Usar ferramentas como chaves de fenda ou martelos.
#
# 3.  **Multitarefa e Eficiência (Multitasking and Efficiency):** Eles trabalham em conjunto! Imagina tocar um instrumento como violão ou piano, onde cada dedo faz uma coisa diferente. Ou mesmo digitar, onde os 10 dedos agem em harmonia para escrever rápido, sem precisar caçar as letras.
#
# 4.  **Sensibilidade (Input/Feedback):** Além de serem "atuadores" (que fazem as coisas), são também "sensores" super potentes. Através deles, a gente sente:
#     *   Texturas (liso, áspero, macio).
#     *   Temperaturas (quente, frio).
#     *   Pressões (se algo é leve ou pesado).
#
# **Em resumo:** Ter 10 dedos é ter um "controlador" orgânico completo, que te permite desde as interações mais delicadas e precisas até as tarefas que exigem força e destreza. É a nossa principal ferramenta para interagir com o mundo, sempre "ligada" e "disponível"! Uma maravilha de engenharia natural, concorda? 😉

# %% [markdown]
# ## 8. Controlando a criatividade com `temperature`
#
# O parâmetro `temperature` controla o nível de criatividade da resposta.
#
# - Valores baixos, como `0.1` ou `0.2`, deixam a resposta mais direta e previsível.
# - Valores médios, como `0.5`, equilibram clareza e criatividade.
# - Valores altos, como `0.9`, deixam a resposta mais criativa, mas menos previsível.

# %%
pergunta = "Crie uma analogia simples para explicar o que é machine learning."

resposta = cliente.models.generate_content(
    model=MODELO,
    contents=pergunta,
    config={
        "temperature": 0.7,
        "system_instruction": INSTRUCAO_SISTEMA
    }
)

print(resposta.text)

# %% [markdown]
# ## 9. Limitando o tamanho da resposta
#
# O parâmetro `max_output_tokens` ajuda a limitar o tamanho da resposta.
#
# Isso é útil para economizar uso da API e evitar respostas muito longas.

# %%
resposta = cliente.models.generate_content(
    model=MODELO,
    contents="Explique o que é Python em uma resposta curta.",
    config={
        "system_instruction": INSTRUCAO_SISTEMA,
        "max_output_tokens": 120
    }
)

print(resposta.text)
# Out:
# E aí,

# %% [markdown]
# ## 10. Chat simples com histórico
#
# Um chatbot precisa lembrar das mensagens anteriores.
#
# Para isso, vamos guardar o histórico em uma lista.
#
# Cada mensagem será armazenada com um papel:
#
# - `user`: mensagem enviada pelo usuário;
# - `model`: resposta gerada pela IA.

# %%
historico = []

def conversar(mensagem_usuario: str) -> str:
    """
    Envia uma mensagem para o Gemini usando o histórico da conversa.
    """

    historico.append({
        "role": "user",
        "parts": [{"text": mensagem_usuario}]
    })

    resposta = cliente.models.generate_content(
        model=MODELO,
        contents=historico,
        config={
            "system_instruction": INSTRUCAO_SISTEMA,
            "temperature": 0.9
        }
    )

    texto_resposta = resposta.text

    historico.append({
        "role": "model",
        "parts": [{"text": texto_resposta}]
    })

    return texto_resposta

# %%
print(conversar("Meu nome é Pedro, estou aprendendo Python, tenho 17 anos, moro no bairro 120 santana de parnaiba, tenho um cachorro chamado feroz de 4 anos, estudo no carlos alberto e tenho grandes interreses na área de tecnologia."))
# Out:
# E aí, Pedro! Que legal que você tá aprendendo Python e tem um Feroz em casa! Santana de Parnaíba é um lugar massa!
#
# É show de bola que você tá explorando a área de tecnologia. É um caminho com muita coisa bacana e um monte de oportunidades.
#
# Eu sou seu professor de tecnologia por aqui, e minha missão é te ajudar a entender tudo de um jeito bem tranquilo, com exemplos práticos e sem complicação, pra você voar nessa área.
#
# **O que você quer aprender hoje?**
#
# *   Tá com alguma dúvida sobre algo que viu em Python?
# *   Quer entender um conceito de programação (tipo "o que é um algoritmo?" ou "pra que serve uma variável?")?
# *   Ou de repente quer saber mais sobre inteligência artificial, como funciona um site, ou até sobre games?
#
# É só mandar a brasa com a sua pergunta! Tô aqui pra te ajudar. 😉

# %%
print(conversar("Qual é o meu nome e o que eu estou aprendendo e oque você sabe sobre mim ?"))
# Out:
# Beleza, Pedro! Vamos lá, eu sei um bocado sobre você:
#
# 1.  **Seu nome é Pedro.**
# 2.  Você está **aprendendo Python**.
# 3.  Sei que você tem **17 anos**, mora no bairro **120 em Santana de Parnaíba**, tem um cachorro chamado **Feroz** de **4 anos**, estuda no colégio **Carlos Alberto** e tem **grandes interesses na área de tecnologia**.
#
# Acertou tudo? 😉

# %% [markdown]
# ## 11. Limpando o histórico
#
# Se quisermos começar uma conversa nova, basta limpar a lista `historico`.

# %%
historico.clear()
print("Histórico limpo!")

# %% [markdown]
# ## 12. Pedindo resposta em formato JSON
#
# Às vezes queremos que a IA responda em um formato estruturado.
#
# Isso é útil quando queremos usar a resposta dentro de outro programa.

# %%
prompt = """
Crie um plano de estudos simples sobre Python básico.

Responda somente em JSON válido, seguindo este formato:
{
  "tema": "",
  "duracao_dias": 0,
  "topicos": [],
  "projeto_final": ""
}
"""

resposta = cliente.models.generate_content(
    model=MODELO,
    contents=prompt,
    config={
        "temperature": 0.2,
        "system_instruction": "Você responde somente em JSON válido, sem texto antes ou depois."
    }
)

print(resposta.text)

# %% [markdown]
# ## 13. Exercícios para os alunos
#
# Faça as atividades abaixo:
#
# 1. Altere o prompt da primeira pergunta para pedir uma explicação sobre banco de dados.
# 2. Mude a `temperature` para `0.1` e depois para `0.9`. Compare as respostas.
# 3. Crie uma instrução de sistema dizendo que a IA deve responder como um professor do SENAI.
# 4. Use o chat com histórico para fazer três perguntas conectadas sobre Python.
# 5. Peça para a IA gerar uma lista de exercícios em JSON.

# %% [markdown]
# ## 14. Desafio final
#
# Crie uma função chamada `gerar_exercicios()` que receba um tema e retorne 5 exercícios sobre esse tema.
#
# Exemplo esperado:
#
# ```python
# gerar_exercicios("listas em Python")
# ```
#
# A função deve pedir para o Gemini gerar exercícios com:
#
# - enunciado;
# - nível de dificuldade;
# - resposta esperada.

# %%
def gerar_exercicios(tema: str) -> str:
    prompt = f"""
    Crie 5 exercícios sobre o tema: {tema}.

    Para cada exercício, informe:
    - enunciado;
    - nível de dificuldade;
    - resposta esperada.

    Responda em português do Brasil.
    """

    resposta = cliente.models.generate_content(
        model=MODELO,
        contents=prompt,
        config={
            "system_instruction": INSTRUCAO_SISTEMA,
            "temperature": 0.4
        }
    )

    return resposta.text

# %%
print(gerar_exercicios("listas em Python"))

# %% [markdown]
# ## Fechamento
#
# Neste notebook você viu o básico para usar o Gemini com Python:
#
# - instalação da biblioteca;
# - configuração da chave;
# - envio de prompts;
# - instruções de sistema;
# - parâmetros básicos;
# - histórico de conversa;
# - resposta estruturada;
# - criação de exercícios com IA.
#
# A partir daqui, você pode evoluir para projetos com interface web usando Streamlit ou Gradio.
